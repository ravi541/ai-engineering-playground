# %%
pip install --upgrade seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\raviteja\appdata\roaming\python\python311\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\raviteja\appdata\roaming\python\python311\site-packages (from seaborn) (3.0.2)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.9-cp311-cp311-win_amd64.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      ---------------------- --------------- 30.7/52.8 kB 259.2 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 340.8 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl.metadata (121 kB)
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/121.0 kB ? eta -:--:--
#      ------------------- ------------------- 61.4/121.0 kB 1.1 MB/s eta 0:00:01
#      ----------------------------------- -- 112.6/121.0 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 121.0/121.0 kB 886.4 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\raviteja\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\raviteja\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raviteja\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\raviteja\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\raviteja\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ------------------ --------------------- 133.1/294.9 kB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# Downloading matplotlib-3.10.9-cp311-cp311-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.2 MB 6.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/8.2 MB 4.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/8.2 MB 3.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/8.2 MB 3.5 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/8.2 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/8.2 MB 3.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/8.2 MB 3.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.2/8.2 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.4/8.2 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/8.2 MB 3.4 MB/s eta 0:00:02
#    -------- ------------------------------- 1.7/8.2 MB 3.3 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.2 MB 3.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.2 MB 3.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.2 MB 3.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.2/8.2 MB 3.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.3/8.2 MB 3.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.2 MB 3.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.5/8.2 MB 3.0 MB/s eta 0:00:02
#    ------------ --------------------------- 2.5/8.2 MB 2.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.5/8.2 MB 2.7 MB/s eta 0:00:03
#    ------------- -------------------------- 2.7/8.2 MB 2.8 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.2 MB 2.8 MB/s eta 0:00:02
#    -------------- ------------------------- 3.0/8.2 MB 2.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.2/8.2 MB 2.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.3/8.2 MB 2.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.5/8.2 MB 2.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.6/8.2 MB 2.9 MB/s eta 0:00:02
#    ------------------ --------------------- 3.9/8.2 MB 3.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.0/8.2 MB 3.0 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.2 MB 3.0 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.2 MB 3.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.6/8.2 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.8/8.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 4.9/8.2 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 5.1/8.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.3/8.2 MB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.4/8.2 MB 3.2 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.2 MB 3.1 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.9/8.2 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------- -------- 6.4/8.2 MB 3.1 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.2 MB 3.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.2 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.2 MB 3.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.2/8.2 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.4/8.2 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.2 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.8/8.2 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  8.2/8.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  8.2/8.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 3.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    ------------------------------------ --- 204.8/225.2 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 225.2/225.2 kB 3.4 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.4 MB 6.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.4 MB 4.5 MB/s eta 0:00:01
#    --------- ------------------------------ 0.6/2.4 MB 4.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.4 MB 4.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.4 MB 4.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.2/2.4 MB 4.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.4 MB 4.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.5/2.4 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.4 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.7/2.4 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.9/2.4 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.2/2.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 3.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    ------------------------------ --------- 92.2/122.8 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 122.8/122.8 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 pyparsing-3.3.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings

warnings.filterwarnings("ignore",category=FutureWarning)

# %%
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import matplotlib.pyplot as plt

tips =sns.load_dataset("tips")

sns.set_theme(style="darkgrid")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.to_csv("tips_dataset.csv",index=False)

# %%
plt.figure(figsize=(8,6))

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="time",size="size",palette="deep")
plt.title("Scatter Plot: Total bill vs tip by time and size")
plt.show()
