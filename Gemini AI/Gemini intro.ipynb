# %%
# pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires protobuf<5,>=4.25.3, but you have protobuf 5.29.6 which is incompatible.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['GEMINI_API_KEY']='AQ.Ab8RN6I07DHHWU0bQn99bbZn8fSF6AQ6a6CltOIO-MYajZVmTA'

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
response = model.generate_content("Give me difference between Gen AI vs ML vs agentic ai vs agents")
print(response.text)
# Out:
# To understand the differences between these four terms, it is helpful to view them as a hierarchy: **Machine Learning** is the foundation, **Gen AI** is a specific type of ML, **Agents** are a functional design, and **Agentic AI** is the advanced realization of those agents using Gen AI.
#
# Here is a breakdown of the differences:
#
# ---
#
# ### 1. Machine Learning (ML)
# **The Foundation.**
# Machine Learning is the broad field of AI where computers learn patterns from data to make predictions or decisions without being explicitly programmed for every scenario.
#
# *   **Core Function:** Pattern recognition and prediction.
# *   **What it does:** It takes input data and gives you an output (classification or a number).
# *   **Output:** "This is a cat," "The stock price will be $50," or "This email is spam."
# *   **Analogy:** A calculator that has learned to recognize the difference between a "2" and a "3" by looking at millions of handwritten notes.
#
# ### 2. Generative AI (Gen AI)
# **The Content Creator.**
# A subset of Machine Learning (specifically Deep Learning) that focuses on creating *new* data that looks like the data it was trained on.
#
# *   **Core Function:** Creation and Synthesis.
# *   **What it does:** It predicts the next most likely element in a sequence (a word, a pixel, a note) to create something original.
# *   **Output:** An essay, a realistic image, a snippet of code, or a song.
# *   **Analogy:** A highly skilled mimic who has read every book in the world and can now write a new story in the style of any author you choose.
#
# ### 3. AI Agents
# **The Worker.**
# In a general sense, an agent is a software entity that can perform tasks on behalf of a user. In the AI context, an agent is a system designed to perceive its environment and take actions to achieve a goal.
#
# *   **Core Function:** Task execution.
# *   **What it does:** It follows a set of instructions or a workflow to complete a job (e.g., "If X happens, do Y").
# *   **Output:** A completed task (booking a flight, moving a file, scraping a website).
# *   **Analogy:** A specialized factory robot. It knows how to do one specific job (like welding) very well when triggered.
#
# ### 4. Agentic AI
# **The Autonomous Reasoner.**
# Agentic AI refers to AI systems (usually powered by Gen AI) that possess **autonomy, reasoning, and tool-use capabilities**. Unlike a standard chatbot that just talks, Agentic AI *thinks* through a problem, breaks it into steps, and executes them.
#
# *   **Core Function:** Reasoning and Autonomy.
# *   **What it does:** You give it a high-level goal (e.g., "Research this company and write a summary of their competitors"). The AI decides *which* tools to use, *how* to search, and *how* to fix its own errors.
# *   **Output:** A complex, multi-step solution completed without human intervention.
# *   **Analogy:** A high-level executive assistant. You don't tell them how to use a phone or how to book a hotel; you just say "Get me to London by Tuesday," and they figure out the rest.
#
# ---
#
# ### Comparison Summary Table
#
# | Feature | Machine Learning | Generative AI | AI Agents | Agentic AI |
# | :--- | :--- | :--- | :--- | :--- |
# | **Primary Goal** | Predict or Classify | Create new content | Execute a task | Achieve a complex goal |
# | **Input** | Structured Data | Prompts / Data | Triggers / Commands | High-level objectives |
# | **Output** | Labels / Numbers | Text / Images / Code | Actions | Multi-step workflows |
# | **Autonomy** | Low (Reactive) | Low (Needs prompt) | Medium (Follows rules) | High (Self-directing) |
# | **Example** | Netflix Recommendations | ChatGPT writing a poem | A simple Customer Service bot | An AI that researches, writes, and publishes a blog post |
#
# ---
#
# ### How they work together:
# Imagine you want to plan a vacation:
# 1.  **ML** predicts which hotels you are likely to prefer based on your history.
# 2.  **Gen AI** writes a personalized travel itinerary for you.
# 3.  **An Agent** is the software button that clicks "Book" and sends your credit card info to the hotel.
# 4.  **Agentic AI** is the "Travel Manager" that you tell: *"I have $2000, I want to go somewhere sunny in March. Find the best deal, book it, and handle any flight cancellations if they happen."* (It uses ML to predict, Gen AI to reason/write, and Agents to execute).

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('.',' *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _:True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-robotics-er-2-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
