# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\Raviteja\OneDrive\Desktop\CNN- Happy or Sad\training\sad\4images4.png")

# %%
input
# Out:
# array([[[208, 207, 203],
#         [208, 207, 203],
#         [208, 207, 203],
#         ...,
#         [217, 212, 203],
#         [217, 212, 203],
#         [217, 212, 203]],
#
#        [[208, 207, 203],
#         [208, 207, 203],
#         [208, 207, 203],
#         ...,
#         [217, 212, 203],
#         [217, 212, 203],
#         [217, 212, 203]],
#
#        [[208, 207, 203],
#         [208, 207, 203],
#         [208, 207, 203],
#         ...,
#         [217, 212, 203],
#         [217, 212, 203],
#         [217, 212, 203]],
#
#        ...,
#
#        [[233, 228, 225],
#         [233, 228, 225],
#         [233, 228, 225],
#         ...,
#         [180, 196, 212],
#         [180, 196, 212],
#         [179, 195, 211]],
#
#        [[233, 228, 225],
#         [233, 228, 225],
#         [233, 228, 225],
#         ...,
#         [180, 196, 212],
#         [180, 196, 212],
#         [180, 196, 212]],
#
#        [[233, 228, 225],
#         [233, 228, 225],
#         [233, 228, 225],
#         ...,
#         [182, 198, 214],
#         [182, 198, 214],
#         [182, 198, 214]]], shape=(597, 335, 3), dtype=uint8)

# %%
cv2.imshow('Sad Image',input)


# Wait until a key is pressed
cv2.waitKey(0)

# Close all windows
cv2.destroyAllWindows()

# %%
print('Height of Image:', int(input.shape[0]),'pixels')
print('Width of Image:', int(input.shape[1]),'pixels')
# Out:
# Height of Image: 597 pixels
# Width of Image: 335 pixels

# %%
cv2.imwrite('Output.jpg',input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Raviteja\\AVSCODE\\ai-engineering-playground\\OPENCV\\Basic opencv code'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\python.exe
