# %%
# pip install -U langgraph
# Out:
# Requirement already satisfied: langgraph in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.2.9)
# Collecting langgraph
#   Downloading langgraph-1.2.10-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph) (1.5.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph) (3.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.8.6)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages (from langchain-core<2,>=1.4.7->langgraph) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (4.12.0)
# Requirement already satisfied: certifi in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.6.2)
# Downloading langgraph-1.2.10-py3-none-any.whl (247 kB)
# Installing collected packages: langgraph
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.9
#     Uninstalling langgraph-1.2.9:
#       Successfully uninstalled langgraph-1.2.9
# Successfully installed langgraph-1.2.10
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from IPython.display import Image, display

# %%
class MyState(TypedDict):
    message: str
    
#Define the start node
def start_node(State: MyState) -> MyState:
     return {"message": State["message"]}
 
def end_node(State: MyState) -> MyState:
     return State
 
builder = StateGraph(MyState)

# %%
id(builder)
# Out:
# 1844002280016

# %%
builder

# %%
builder.add_node("start",start_node)
builder.add_node("end",end_node)

# %%
builder.set_entry_point("start")
builder.add_edge("start","end")
builder.add_edge("end",END)

# %%
graph = builder.compile()

result = graph.invoke({"message":"What is AI vs ML"})
print("Final result:", result["message"])
# Out:
# Final result: What is AI vs ML
