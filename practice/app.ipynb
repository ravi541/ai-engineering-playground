# %% [markdown]
# #Python Practice

# %%
def wish():
    print('Hello')
    wish()
    
wish()

# %%
import sys
sys.setrecursionlimit(100)
sys.getrecursionlimit()
# Out:
# 100

# %%
import sys
sys.setrecursionlimit(40)

print(sys.getrecursionlimit())

i = 0

def wish():
    global i
    i +=1
    print('Hello',i)
    wish()
    
wish()
# Out:
# 40
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5
# Hello 6
# Hello 7
# Hello 8
# Hello 9
# Hello 10
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Raviteja\AppData\Local\Temp\ipykernel_9448\2205576211.py", line 14, in <module>
#     wish()
#   File "C:\Users\Raviteja\AppData\Local\Temp\ipykernel_9448\2205576211.py", line 12, in wish
#     wish()
#   File "C:\Users\Raviteja\AppData\Local\Temp\ipykernel_9448\2205576211.py", line 12, in wish
#     wish()
#   File "C:\Users\Raviteja\AppData\Local\Temp\ipykernel_9448\2205576211.py", line 12, in wish
#     wish()
#   [Previous line repeated 7 more times]
#   File "C:\Users\Raviteja\AppData\Local\Temp\ipykernel_9448\2205576211.py", line 11, in wish
#     print('Hello',i)
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3053, in write
#     result = original_write(data, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py", line 747, in write
#     is_child = not self._is_master_process()
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py", line 617, in _is_master_process
#     return os.getpid() == self._master_pid
#            ^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2201, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1064, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 872, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 757, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 859, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 77, in collapse_repeated
#     for is_highlighted, group in itertools.groupby(
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 45, in highlight_unique
#     counts = Counter(lst)
#              ^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py", line 599, in __init__
#     self.update(iterable, **kwds)
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\collections\__init__.py", line 681, in update
#     if isinstance(iterable, _collections_abc.Mapping):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen abc>", line 119, in __instancecheck__
# RecursionError: maximum recursion depth exceeded in comparison
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3641, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3723, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2209, in showtraceback
#     traceback.print_exc()
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 180, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 728, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 433, in _extract_from_extended_frame_gen
#     f.line
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 318, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2201, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1064, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 872, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 757, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 859, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 224, in executing
#     source = cls.for_frame(frame)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 143, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 172, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 177, in _for_filename_and_lines
#     source_cache = cls._class_local('__source_cache_with_lines', {}) # type: Dict[Tuple[str, Sequence[str]], Source]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 257, in _class_local
#     result = cls.__dict__.get(name, default)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\tokenize.py", line 400, in open
#     text = TextIOWrapper(buffer, encoding, line_buffering=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen codecs>", line 310, in __init__
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3178, in _run_cell
#     result = runner(coro)
#              ^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3400, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3660, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2209, in showtraceback
#     traceback.print_exc()
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 180, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 787, in __init__
#     context = TracebackException(
#               ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 728, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 433, in _extract_from_extended_frame_gen
#     f.line
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\traceback.py", line 318, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\tokenize.py", line 404, in open
#     buffer.close()
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\tokenize.py", line 398, in open
#     encoding, lines = detect_encoding(buffer.readline)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\tokenize.py", line 367, in detect_encoding
#     first = read_or_stop()
#             ^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\tokenize.py", line 325, in read_or_stop
#     return readline()
#            ^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2201, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1064, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 872, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 757, in format_exception_as_a_whole
#     records = self.get_records(etb, context, tb_offset) if etb else []
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 859, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 224, in executing
#     source = cls.for_frame(frame)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 143, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 163, in for_filename
#     lines = get_lines()
#             ^^^^^^^^^^^
#   File "C:\Users\Raviteja\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 158, in get_lines
#     return linecache.getlines(cast(str, filename), module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\tokenize.py", line 404, in open
#     buffer.close()
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
# Factorial with recurrion
# Recursion is a programming technique in which a function calls itself to solve a problem by breaking it into smaller versions of the same problem.

# In simple words:

# A function calling itself is called Recursion.

def fact(i):
    if i==1:
        return 1
    return i * fact(i-1)

res = fact(5)
print(res)
# Out:
# 120
