# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc= nlp("Data sciene and ai & gen ai has great career ahead")

# %%
doc
# Out:
# Data sciene and ai & gen ai has great career ahead

# %%
for token in doc:
    print(token.pos_)
# Out:
# NOUN
# NOUN
# CCONJ
# PROPN
# CCONJ
# PROPN
# PROPN
# VERB
# ADJ
# NOUN
# ADV

# %%
for token in doc:
    print(token.text,':',token.pos_)
# Out:
# Data : NOUN
# sciene : NOUN
# and : CCONJ
# ai : PROPN
# & : CCONJ
# gen : PROPN
# ai : PROPN
# has : VERB
# great : ADJ
# career : NOUN
# ahead : ADV

# %%
for token in doc:
    print(token.text,':',token.pos_,'-->',token.lemma_,token.dep_)
# Out:
# Data : NOUN --> datum compound
# sciene : NOUN --> sciene nsubj
# and : CCONJ --> and cc
# ai : PROPN --> ai conj
# & : CCONJ --> & cc
# gen : PROPN --> gen conj
# ai : PROPN --> ai conj
# has : VERB --> have ROOT
# great : ADJ --> great amod
# career : NOUN --> career dobj
# ahead : ADV --> ahead advmod

# %%
for token in doc:
    print(token.text,':',token.pos_,'-->',token.lemma_,token.dep_, token.tag_,token.shape_,token.is_alpha,token.is_stop)
# Out:
# Data : NOUN --> datum compound NNS Xxxx True False
# sciene : NOUN --> sciene nsubj NN xxxx True False
# and : CCONJ --> and cc CC xxx True True
# ai : PROPN --> ai conj NNP xx True False
# & : CCONJ --> & cc CC & False False
# gen : PROPN --> gen conj NNP xxx True False
# ai : PROPN --> ai conj NNP xx True False
# has : VERB --> have ROOT VBZ xxx True True
# great : ADJ --> great amod JJ xxxx True False
# career : NOUN --> career dobj NN xxxx True False
# ahead : ADV --> ahead advmod RB xxxx True False

# %%
for token in doc:
    print(
        f"""
Word       : {token.text}
POS        : {token.pos_}
Lemma      : {token.lemma_}
Dependency : {token.dep_}
Tag        : {token.tag_}
Shape      : {token.shape_}
Is Alpha   : {token.is_alpha}
Is Stopword: {token.is_stop}
------------------------------
"""
    )
# Out:
# Word       : Data
# POS        : NOUN
# Lemma      : datum
# Dependency : compound
# Tag        : NNS
# Shape      : Xxxx
# Is Alpha   : True
# Is Stopword: False
# ------------------------------
#
#
# Word       : sciene
# POS        : NOUN
# Lemma      : sciene
# Dependency : nsubj
# Tag        : NN
# Shape      : xxxx
# Is Alpha   : True
# Is Stopword: False
# ------------------------------
#
#
# Word       : and
# POS        : CCONJ
# Lemma      : and
# Dependency : cc
# Tag        : CC
# Shape      : xxx
# Is Alpha   : True
# Is Stopword: True
# ------------------------------
#
#
# Word       : ai
# POS        : PROPN
# Lemma      : ai
# Dependency : conj
# Tag        : NNP
# Shape      : xx
# Is Alpha   : True
# Is Stopword: False
# ------------------------------
#
#
# Word       : &
# POS        : CCONJ
# Lemma      : &
# Dependency : cc
# Tag        : CC
# Shape      : &
# Is Alpha   : False
# Is Stopword: False
# ------------------------------
#
#
# Word       : gen
# ...

# %%
for token in doc:
    print(
        f"{token.text:10} | "
        f"POS: {token.pos_:6} | "
        f"Lemma: {token.lemma_:10} | "
        f"Dep: {token.dep_:8} | "
        f"Tag: {token.tag_:5} | "
        f"Shape: {token.shape_:8} | "
        f"Alpha: {token.is_alpha} | "
        f"Stopword: {token.is_stop}"
    )
# Out:
# Data       | POS: NOUN   | Lemma: datum      | Dep: compound | Tag: NNS   | Shape: Xxxx     | Alpha: True | Stopword: False
# sciene     | POS: NOUN   | Lemma: sciene     | Dep: nsubj    | Tag: NN    | Shape: xxxx     | Alpha: True | Stopword: False
# and        | POS: CCONJ  | Lemma: and        | Dep: cc       | Tag: CC    | Shape: xxx      | Alpha: True | Stopword: True
# ai         | POS: PROPN  | Lemma: ai         | Dep: conj     | Tag: NNP   | Shape: xx       | Alpha: True | Stopword: False
# &          | POS: CCONJ  | Lemma: &          | Dep: cc       | Tag: CC    | Shape: &        | Alpha: False | Stopword: False
# gen        | POS: PROPN  | Lemma: gen        | Dep: conj     | Tag: NNP   | Shape: xxx      | Alpha: True | Stopword: False
# ai         | POS: PROPN  | Lemma: ai         | Dep: conj     | Tag: NNP   | Shape: xx       | Alpha: True | Stopword: False
# ...

# %%
import spacy 
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)
stopwords
# Out:
# ['one',
#  'more',
#  'meanwhile',
#  'thereafter',
#  'why',
#  'few',
#  'sixty',
#  "'d",
#  'he',
#  'eleven',
#  'however',
#  'my',
#  'therein',
#  'own',
#  'myself',
#  'thence',
#  'n‘t',
#  'call',
#  'but',
#  'onto',
#  'name',
#  'at',
#  'neither',
#  'eight',
#  'above',
#  'various',
#  'what',
#  'those',
#  'becomes',
#  'whereby',
#  'much',
#  'for',
#  'upon',
#  'herein',
#  'must',
#  'n’t',
#  "'ve",
#  'some',
#  'although',
#  'ca',
#  "'s",
#  'everyone',
#  'hereupon',
#  'which',
#  'has',
#  'either',
#  'still',
#  'via',
#  'whoever',
#  'nevertheless',
#  'same',
#  'against',
#  'together',
#  'regarding',
#  '’ve',
#  'will',
#  'ourselves',
#  'because',
#  'doing',
#  "'m",
#  '’d',
#  'might',
#  'every',
#  'another',
#  'front',
#  'also',
#  'several',
#  'whether',
#  'once',
#  'then',
#  'towards',
#  'whereas',
#  'used',
#  'get',
#  'being',
#  'they',
#  'them',
#  'among',
#  'else',
#  'does',
#  'cannot',
#  'me',
#  '‘d',
#  'i',
# ...
