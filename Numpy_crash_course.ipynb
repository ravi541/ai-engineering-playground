# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.5'

# %%
np.ones(5,dtype=boolean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.ones(5,dtype=boolean)
#
# NameError: name 'boolean' is not defined
