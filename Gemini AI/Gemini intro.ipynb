# %%
# pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires protobuf<5,>=4.25.3, but you have protobuf 5.29.6 which is incompatible.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['GEMINI_API_KEY']='AQ.Ab8RN6IVh566z7IHsNMEr0Z2qODluK3kZf151zyX1w'

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
response = model.generate_content("Give me difference between Gen AI vs ML vs agentic ai vs agents")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
# ...

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('.',' *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _:True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# ...

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
response  = model.generate_content("Create a tale for comparision between Data science vs machine learning vs ai")
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\api_core\grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      54 try:
# ---> 55     return callable_(*args, **kwargs)
#      56 except grpc.RpcError as exc:
#
# File c:\Users\Raviteja\AppData\Local\Programs\Python\Python311\Lib\site-packages\grpc\_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
# ...

# %%
to_markdown(response.text)

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6IVh566z7IHscg4p1TZ4NMEr0Z2qODluK3kZf151zyX1w")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="Give me difference between Gen AI vs ML vs Agentic AI vs AI Agents"
)

print(response.text)
# Out:
# Understanding the differences between these terms is best done by looking at them as an evolution: from **learning** from data, to **creating** content, to **taking action** autonomously.
#
# Here is the breakdown of how they differ and how they relate to one another.
#
# ---
#
# ### 1. Machine Learning (ML)
# **The Foundation**
# Machine Learning is the broad field of AI that focuses on building systems that learn patterns from data to make predictions or decisions.
#
# *   **How it works:** You feed it a massive dataset (e.g., historical house prices), and it learns the mathematical relationship between variables to predict future outcomes.
# *   **Primary Goal:** Prediction, Classification, and Recommendation.
# *   **Examples:** Netflix recommendations, credit card fraud detection, weather forecasting.
# *   **Analogy:** A student studying thousands of past exam papers to predict what questions will be on the next test.
#
# ### 2. Generative AI (Gen AI)
# **The Creator**
# ...
