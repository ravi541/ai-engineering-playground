# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from PIL import Image

# %%
pic = Image.open(r'C:\Users\Raviteja\Downloads\CuteBoy.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)
pic_arr
# Out:
# array([[[171, 154, 128],
#         [170, 153, 127],
#         [166, 152, 125],
#         ...,
#         [165, 130, 110],
#         [166, 131, 111],
#         [166, 134, 111]],
#
#        [[171, 154, 128],
#         [169, 153, 127],
#         [166, 152, 126],
#         ...,
#         [178, 143, 123],
#         [178, 143, 123],
#         [167, 135, 112]],
#
#        [[169, 153, 128],
#         [168, 152, 127],
#         [166, 152, 126],
#         ...,
#         [186, 151, 129],
#         [186, 151, 129],
#         [170, 138, 113]],
#
#        ...,
#
#        [[174,  79,  59],
#         [191,  96,  76],
#         [232, 137, 117],
#         ...,
#         [172, 136, 102],
#         [165, 129,  95],
#         [170, 131, 102]],
#
#        [[200, 105,  85],
#         [177,  82,  62],
#         [208, 113,  93],
#         ...,
#         [175, 139, 103],
#         [168, 132,  96],
#         [163, 124,  95]],
#
#        [[220, 108,  88],
#         [197,  88,  67],
#         [214, 112,  89],
# ...

# %%
plt.imshow(pic_arr)

# %%
pic_arr.shape
# Out:
# (225, 225, 3)
